# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd
import os
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("C:/Users/admin/Desktop/JuliaDQMC/code/")
from DP_Lib import *

# %%
# 数据路径处理
base_path = "./"
data = pd.read_csv(os.path.join(base_path, "R_CDW_H0.csv"), header=None)
L = data[0].values
R11 = data[1].values
R22 = data[2].values
R12 = data[3].values
R21 = data[4].values

# %%
plt.figure(figsize=(18,5))

plt.subplot(1,2,1)

plt.plot(L, R11, 'o', label='R11')
plt.plot(L, R22, 's', label='R22')

plt.xlabel(r'$\Theta$')
plt.ylabel('R11 and R22')
plt.legend()

plt.subplot(1,2,2)

plt.plot(L, R12, 'o', label='R12')
plt.plot(L, R21, 's', label='R21')

plt.xlabel(r'$\Theta$')
plt.ylabel('R12 and R21')   
plt.legend()
plt.show()
